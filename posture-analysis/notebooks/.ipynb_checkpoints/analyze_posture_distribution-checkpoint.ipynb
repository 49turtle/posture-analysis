# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# JSON 파일 로드
with open('../data/processed/labeled_keypoints_01.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
df = pd.json_normalize(data)
df.head()
# Out:
#      source         label details  \
# 0  openpose  good_posture      []
# 1  openpose  good_posture      []
# 2  openpose  good_posture      []
# 3  openpose  good_posture      []
# 4  openpose  good_posture      []
#
#                                       keypoints.nose  \
# 0  [476.2963562011719, 85.68756866455078, 0.92947...
# 1  [474.8432922363281, 87.0812759399414, 0.929795...
# 2  [471.93377685546875, 79.78460693359375, 0.8496...
# 3  [470.42425537109375, 68.08300018310547, 0.8375...
# 4  [470.4664001464844, 62.152488708496094, 0.8563...
#
#                                       keypoints.neck  \
# 0  [510.05682373046875, 122.4376449584961, 0.9101...
# 1  [508.603271484375, 123.84746551513672, 0.89422...
# 2  [507.18280029296875, 120.92947387695312, 0.852...
# 3  [507.1634521484375, 110.60973358154297, 0.8784...
# 4  [505.6841125488281, 100.31273651123047, 0.8794...
#
#                             keypoints.right_shoulder  \
# 0  [479.2939453125, 123.85235595703125, 0.8596313...
# 1  [480.71307373046875, 125.33197784423828, 0.839...
# 2  [482.21148681640625, 122.39720916748047, 0.849...
# 3  [485.13165283203125, 112.07340240478516, 0.872...
# 4  [485.1353759765625, 103.30530548095703, 0.8226...
#
#                                keypoints.right_elbow  \
# 0  [474.8530578613281, 179.68255615234375, 0.9185...
# 1  [476.34783935546875, 179.68701171875, 0.907987...
# 2  [486.59832763671875, 169.43359375, 0.800019383...
# 3  [488.1319274902344, 157.6170196533203, 0.74482...
# 4  [493.9410095214844, 148.8695831298828, 0.63583...
#
#                                keypoints.right_wrist  \
# 0  [441.0402526855469, 191.35887145996094, 0.8812...
# 1  [442.609130859375, 189.9194793701172, 0.847775...
# 2  [451.35577392578125, 181.20265197753906, 0.933...
# 3  [460.17681884765625, 170.79937744140625, 0.895...
# 4  [464.6170654296875, 160.54676818847656, 0.8889...
#
#                              keypoints.left_shoulder  \
# 0  [535.1519165039062, 120.94384002685547, 0.8495...
# 1  [533.6187744140625, 122.35694885253906, 0.8798...
# 2  [532.12109375, 115.09188842773438, 0.807927846...
# 3  [529.2102661132812, 106.26585388183594, 0.7839...
# 4  [526.2529296875, 97.38298797607422, 0.80031466...
#
#                                 keypoints.left_elbow  ...  \
# 0  [555.6515502929688, 176.74461364746094, 0.8208...  ...
# 1  [538.0183715820312, 181.06942749023438, 0.8589...  ...
# 2  [523.3798828125, 173.81881713867188, 0.8493772...  ...
# 3  [517.4261474609375, 162.07687377929688, 0.8145...  ...
# 4  [511.56884765625, 153.2247314453125, 0.8907380...  ...
#
#                                  keypoints.right_eye  \
# 0  [474.921875, 76.89656829833984, 0.615393161773...
# 1  [474.8219299316406, 76.92866516113281, 0.50855...
# 2  [473.3265075683594, 75.32682037353516, 0.45406...
# 3  [470.4664306640625, 63.61381912231445, 0.45474...
# 4  [470.4308166503906, 53.35260009765625, 0.31065...
#
#                                   keypoints.left_eye keypoints.right_ear  \
# 0  [485.1314392089844, 76.89505767822266, 0.92156...     [0.0, 0.0, 0.0]
# 1  [482.1843566894531, 76.94551086425781, 0.87302...     [0.0, 0.0, 0.0]
# 2  [477.7987060546875, 75.33792877197266, 0.90398...     [0.0, 0.0, 0.0]
# 3  [476.38934326171875, 63.62955093383789, 0.9381...     [0.0, 0.0, 0.0]
# 4  [476.36358642578125, 53.35555648803711, 0.9419...     [0.0, 0.0, 0.0]
#
#                                   keypoints.left_ear  \
# 0  [507.1861572265625, 79.79769134521484, 0.86658...
# 1  [504.26177978515625, 81.2649154663086, 0.83418...
# 2  [501.27410888671875, 75.45639038085938, 0.9330...
# 3  [499.8592834472656, 65.14026641845703, 0.94637...
# 4  [499.8522033691406, 54.80935287475586, 0.92261...
#
#                               keypoints.left_big_toe  \
# 0  [466.05865478515625, 413.1751403808594, 0.7443...
# 1  [538.0258178710938, 338.3182373046875, 0.41723...
# 2  [489.5563049316406, 408.7562255859375, 0.76442...
# 3  [501.3135681152344, 408.7769470214844, 0.76551...
# 4  [510.1468505859375, 405.8865966796875, 0.77846...
#
#                             keypoints.left_small_toe  \
# 0  [476.3603210449219, 416.07354736328125, 0.7889...
# 1  [542.4241333007812, 335.3921813964844, 0.43432...
# 2  [499.8871765136719, 413.1551208496094, 0.77231...
# 3  [511.62713623046875, 411.7127685546875, 0.7650...
# 4  [521.8526611328125, 407.31878662109375, 0.7024...
#
#                                  keypoints.left_heel  \
# 0  [511.6253356933594, 404.34454345703125, 0.8495...
# 1  [536.5286865234375, 304.5182189941406, 0.32226...
# 2  [535.1117553710938, 399.9342346191406, 0.79567...
# 3  [546.7844848632812, 394.10906982421875, 0.7676...
# 4  [554.181640625, 383.8319091796875, 0.715462625...
#
#                              keypoints.right_big_toe  \
# 0  [557.0269165039062, 332.3620910644531, 0.80337...
# 1  [511.5701904296875, 314.82220458984375, 0.0518...
# 2                                    [0.0, 0.0, 0.0]
# 3  [514.5408935546875, 311.8307189941406, 0.11786...
# 4  [499.878662109375, 358.8276672363281, 0.792461...
#
#                            keypoints.right_small_toe  \
# 0  [548.3110961914062, 329.4562683105469, 0.72038...
# 1                                    [0.0, 0.0, 0.0]
# 2                                    [0.0, 0.0, 0.0]
# 3                                    [0.0, 0.0, 0.0]
# 4  [496.8551940917969, 354.40496826171875, 0.6519...
#
#                                 keypoints.right_heel
# 0  [538.0286254882812, 289.8539123535156, 0.62519...
# 1                                    [0.0, 0.0, 0.0]
# 2                                    [0.0, 0.0, 0.0]
# 3  [535.0656127929688, 298.60858154296875, 0.4115...
# 4  [523.3298950195312, 320.5992126464844, 0.69965...
#
# [5 rows x 28 columns]

# %%
# 자세 분포 확인
posture_counts = df['label'].value_counts()
print(posture_counts)
# Out:
# label
# good_posture    893
# Name: count, dtype: int64

# %%
# 자세 분포 시각화
plt.figure(figsize=(10, 6))
sns.barplot(x=posture_counts.index, y=posture_counts.values, palette='viridis')
plt.title('Distribution of Good and Bad Postures')
plt.xlabel('Posture Label')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_6776\1092863413.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=posture_counts.index, y=posture_counts.values, palette='viridis')

# %%
# 나쁜 자세의 세부 사항 확인
bad_posture_details = df[df['label'] == 'bad_posture']['details'].explode()
bad_posture_counts = bad_posture_details.value_counts()
print(bad_posture_counts)
# Out:
# Series([], Name: count, dtype: int64)

# %%
# 나쁜 자세 세부 사항 시각화
plt.figure(figsize=(14, 8))
sns.barplot(x=bad_posture_counts.index, y=bad_posture_counts.values, palette='viridis')
plt.title('Distribution of Bad Posture Details')
plt.xlabel('Bad Posture Detail')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
